# %%
import xarray as xr
import numpy as np
from MSEplots import plots as mpt

# %%
#3h 3d pressure level dataset
merra2_3d=xr.open_dataset('http://weather.rsmas.miami.edu/repository/opendap/3d1eb24f-d927-4541-a81c-4223d76a0989/entry.das')

#3h 3d model level dataset
#merra2_3d=xr.open_dataset('http://weather.rsmas.miami.edu/repository/opendap/8e30966a-652a-4dae-bd5c-c587af29de71/entry.das')



#1h 2d vertically integrated quatities
#merra2_2d=xr.open_dataset('http://weather.rsmas.miami.edu/repository/opendap/65f51c39-ec59-4414-9d3d-8827b5af44b6/entry.das')
#merra2_2d=merra2_2d.sel(time=merra2_3d.time) #match 3h and 1h data times

# %%
t=merra2_3d.t.isel(time=0).sel(lat=10,lon=10)
p=merra2_3d.lev[~np.isnan(t)].values
q=merra2_3d.qv.isel(time=0).sel(lat=10,lon=10)[~np.isnan(t)].values
t=t[~np.isnan(t)].values-273.16
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-9e3d28861423> in <module>()
#       1 t=merra2_3d.t.isel(time=0).sel(lat=10,lon=10)
# ----> 2 p=merra2_3d.lev[~np.isnan(t)].values
#       3 q=merra2_3d.qv.isel(time=0).sel(lat=10,lon=10)[~np.isnan(t)].values
#       4 t=t[~np.isnan(t)].values-273.16
#
# //anaconda/envs/drilsdown/lib/python3.6/site-packages/xarray/core/arithmetic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#      69                            dataset_fill_value=np.nan,
#      70                            kwargs=kwargs,
# ---> 71                            dask='allowed')
#      72
#      73     # this has no runtime function - these are listed so IDEs know these
#
# //anaconda/envs/drilsdown/lib/python3.6/site-packages/xarray/core/computation.py in apply_ufunc(func, *args, **kwargs)
# ...

# %%
mpt.msed_plots(p,t,q,entrain=False)

# %%
mpt.msed_plots(p,t,q,entrain=True)
# Out:
# /home/suvarchal/miniconda3/envs/default/lib/python3.6/site-packages/pint/quantity.py:802: RuntimeWarning: invalid value encountered in true_divide
#   magnitude = magnitude_op(new_self._magnitude, other._magnitude)
# /home/suvarchal/miniconda3/envs/default/lib/python3.6/site-packages/metpy/calc/tools.py:692: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   xp = xp[sorter]
# /home/suvarchal/miniconda3/envs/default/lib/python3.6/site-packages/pint/quantity.py:1281: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# ...
